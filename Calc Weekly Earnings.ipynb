# %%
import numpy as np
import pandas as pd
# Use following code to show all rows or all columns
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
# Reset the pandas defaults.  Here I'm doing this so I don't show every DF row and column 
#pd.reset_option('display')
Global_Team_Cnt = 72

# %%
# read in pga earnings from ESPN.  Use df[1] when there is a playoff, else use df[0]
# Set global variable on what tourney_nb we are working on

# Global_Tourney_Nb = 1
# df = pd.read_html('https://www.espn.com/golf/leaderboard?tournamentId=401703490')
# pga_results = df[1]

# Global_Tourney_Nb = 2
# df = pd.read_html('https://www.espn.com/golf/leaderboard?tournamentId=401703491')
# pga_results = df[0]

Global_Tourney_Nb = 3
df = pd.read_html('https://www.espn.com/golf/leaderboard?tournamentId=401703492')
pga_results = df[0]

pga_results['EARNINGS'] = pga_results['EARNINGS'].str.replace(r'[\$,]', '', regex=True)
pga_results['EARNINGS'] = pd.to_numeric(pga_results['EARNINGS'], errors='coerce').fillna(0)
#print(pga_results['EARNINGS'].dtype)

# Rename golfers to so they merge correctly
pga_results['PLAYER'] = np.where(pga_results['PLAYER']=='Ludvig Åberg','Ludvig Aberg', pga_results['PLAYER'])
pga_results['PLAYER'] = np.where(pga_results['PLAYER']=='Séamus Power','Seamus Power', pga_results['PLAYER'])
pga_results['PLAYER'] = np.where(pga_results['PLAYER']=='Nicolai Højgaard','Nicolai Hojgaard', pga_results['PLAYER'])
pga_results['PLAYER'] = np.where(pga_results['PLAYER']=='Rasmus Højgaard','Rasmus Hojgaard', pga_results['PLAYER'])
pga_results
# Out:
#      Unnamed: 0 POS             PLAYER SCORE  R1  R2  R3  R4  TOT   EARNINGS  \
# 0           NaN   1     Harris English    -8  68  73  66  73  280  1674000.0
# 1           NaN   2        Sam Stevens    -7  69  73  71  68  281  1013700.0
# 2           NaN   3       Andrew Novak    -6  70  72  66  74  282   641700.0
# 3           NaN  T4       Kris Ventura    -5  68  73  71  71  283   418500.0
# 4           NaN  T4         Sungjae Im    -5  69  71  72  71  283   418500.0
# ..          ...  ..                ...   ...  ..  ..  ..  ..  ...        ...
# 150         NaN   -     Philip Knowles    WD  74  --  --  --   74        0.0
# 151         NaN   -       David Lipsky    WD  76  --  --  --   76        0.0
# 152         NaN   -     Hayden Buckley    WD  79  --  --  --   79        0.0
# 153         NaN   -    Emiliano Grillo    WD  78  --  --  --   78        0.0
# 154         NaN   -  Braden Thornberry    WD  --  --  --  --   43        0.0
#
#      FEDEX PTS
# 0          500
# 1          300
# 2          190
# 3          123
# 4          123
# ..         ...
# 150          0
# 151          0
# 152          0
# 153          0
# 154          0
#
# [155 rows x 11 columns]

# %%
# Read in rosters
rosters = pd.read_csv('Rosters.csv')
rosters
# Out:
#                                Team Name            Golfer0  \
# 0                                      7          Aaron Rai
# 1                               #winning    Patrick Cantlay
# 2                       $14 the Hard Way        Justin Rose
# 3                              19th Hole   Hideki Matsuyama
# 4                        2BallChinPutter  Xander Schauffele
# ..                                   ...                ...
# 67                         Walking Bogey    Taylor Pendrith
# 68  Who's Up and Why Aren't They Hitting    Sahith Theegala
# 69                         Wrecking Crew     Davis Thompson
# 70                                 WVU69       Taylor Moore
# 71                            Young Guns         Chris Kirk
#
#               Golfer1           Golfer2           Golfer3  \
# 0   Xander Schauffele     Akshay Bhatia       Min Woo Lee
# 1   Scottie Scheffler  Hideki Matsuyama          Jon Rahm
# 2        Ludvig Aberg   Sahith Theegala           Tom Kim
# 3     Collin Morikawa      Ludvig Aberg         Aaron Rai
# 4   Scottie Scheffler   Rasmus Hojgaard     Rickie Fowler
# ..                ...               ...               ...
# 67       Ludvig Aberg        Sungjae Im  Maverick McNealy
# 68  Scottie Scheffler   Patrick Cantlay       Shane Lowry
# 69  Xander Schauffele     Akshay Bhatia      Brian Harman
# 70     Austin Eckroat     Corey Conners         Eric Cole
# 71      Akshay Bhatia  Matt Fitzpatrick       Nick Dunlap
#
#                     Golfer4                  Golfer5               Golfer6  \
# 0   Christiaan Bezuidenhout           Denny McCarthy          Brian Harman
# 1                       NaN                      NaN                   NaN
# 2               Nick Dunlap            Brooks Koepka     Bryson DeChambeau
# 3         Bryson DeChambeau     Michael Thorbjornsen           Karl Vilips
# 4              Matt McCarty        Bryson DeChambeau         Takumi Kanaya
# ..                      ...                      ...                   ...
# 67           Davis Thompson           Austin Eckroat            Harry Hall
# 68                      NaN                      NaN                   NaN
# 69            Jordan Spieth           Keegan Bradley  Michael Thorbjornsen
# 70             Matt McCarty              Nick Dunlap             Sam Burns
# 71         Robert MacIntyre  Christiaan Bezuidenhout       Taylor Pendrith
#
#                  Golfer7           Golfer8           Golfer9        Golfer10
# 0             Alex Noren               NaN               NaN             NaN
# 1                    NaN               NaN               NaN             NaN
# 2                    NaN               NaN               NaN             NaN
# 3                    NaN               NaN               NaN             NaN
# 4   Michael Thorbjornsen               NaN               NaN             NaN
# ..                   ...               ...               ...             ...
# 67           Ben Griffin  Patrick Fishburn               NaN             NaN
# 68                   NaN               NaN               NaN             NaN
# 69                   NaN               NaN               NaN             NaN
# 70           Sepp Straka   Taylor Pendrith  Maverick McNealy             NaN
# 71             Aaron Rai          Tom Hoge      Brian Harman  Matthieu Pavon
#
# [72 rows x 12 columns]

# %%
# Read in injuries
injuries = pd.read_csv('Injuries.csv')

# Filter down to just this week's injuries
cur_injuries = injuries[injuries['Tourney_Nb'] == Global_Tourney_Nb]

# Convert to a set for faster lookup
cur_injuries_map = cur_injuries.set_index('Golfer')['Salary'].to_dict()
cur_injuries_map
# Out:
# {'Alex Noren': 0.75, 'Xander Schauffele': 6.5, 'Scottie Scheffler': 9.25}

# %%
# Identify injured golfers on each team
for i in range(1, 11):  # For Golfer1 to Golfer10
    golfer_col = f'Golfer{i}'  # Column name for the golfer
    injury_col = f'Injury{i}'  # New column name for injury
    rosters[injury_col] = rosters[golfer_col].map(cur_injuries_map).fillna(0)

# For each team, find the maximum salary of all injured golfers
rosters['Max_Injury_Salary'] = rosters[[f'Injury{i}' for i in range(1,11)]].max(axis=1)
rosters_w_injuries = rosters[rosters['Max_Injury_Salary'] > 0]
rosters_w_injuries
# Out:
#                                Team Name            Golfer0  \
# 0                                      7          Aaron Rai
# 1                               #winning    Patrick Cantlay
# 4                        2BallChinPutter  Xander Schauffele
# 6                               6 Footer     Keegan Bradley
# 7                  7 Iron to the Greener         Alex Noren
# 10                             Above Par          Jason Day
# 15                           Birdie Boys      Wyndham Clark
# 18                          Busch League          Eric Cole
# 19                            Crackem 94          Aaron Rai
# 20                         Double Eagles   Maverick McNealy
# 21                        East West Mics   Matteo Manassero
# 22                             El Quatro  Xander Schauffele
# 23                        Ex-Sepp-tional  Scottie Scheffler
# 30             Go back to your shanties!        Adam Hadwin
# 32                 Golf Ball Whacker Guy       Rory McIlroy
# 38                           I know ball    Collin Morikawa
# 39                      I love broccoli     Sahith Theegala
# 40                      In Rory We Trust         Harry Hall
# 41                   It Burns When I Pee      Rickie Fowler
# 42                     Jackets and Jeans      Cameron Young
# 43              John Daly's Fitness Plan       Andrew Novak
# 46                          Lump of Clay    Tommy Fleetwood
# 47                                Mahady      Akshay Bhatia
# 50                       OTP Sandbaggers        Ben Griffin
# 53                               Rated X      Akshay Bhatia
# 59                     Son of a Squanch!        Adam Hadwin
# 61                      Team Miller Time   Hideki Matsuyama
# 62                      The Hulkamaniacs        Matt Kuchar
# 66                         Turd Ferguson        Shane Lowry
# 68  Who's Up and Why Aren't They Hitting    Sahith Theegala
# 69                         Wrecking Crew     Davis Thompson
#
#               Golfer1           Golfer2            Golfer3  \
# 0   Xander Schauffele     Akshay Bhatia        Min Woo Lee
# 1   Scottie Scheffler  Hideki Matsuyama           Jon Rahm
# 4   Scottie Scheffler   Rasmus Hojgaard      Rickie Fowler
# 6   Xander Schauffele      Ludvig Aberg   Matt Fitzpatrick
# 7   Scottie Scheffler  Maverick McNealy        Sepp Straka
# 10  Xander Schauffele    Russell Henley     Billy Horschel
# 15  Xander Schauffele      Ludvig Aberg     Keegan Bradley
# 18  Xander Schauffele   Tommy Fleetwood   Robert MacIntyre
# 19  Scottie Scheffler    Russell Henley           Tom Hoge
# 20  Scottie Scheffler           Tom Kim          Cam Davis
# 21  Xander Schauffele    Will Zalatoris    Rasmus Hojgaard
# 22  Scottie Scheffler     Cameron Young           Jon Rahm
# 23  Xander Schauffele      Ludvig Aberg     Davis Thompson
# 30     Viktor Hovland   Tommy Fleetwood          Jason Day
# 32  Xander Schauffele      Ludvig Aberg           Max Homa
# 38          Aaron Rai     Akshay Bhatia  Scottie Scheffler
# 39  Scottie Scheffler     Akshay Bhatia        Shane Lowry
# 40       Rory McIlroy     Justin Thomas          Jason Day
# 41      Justin Thomas         Sam Burns        Shane Lowry
# 42       Ludvig Aberg          Max Homa     Austin Eckroat
# 43          Sam Burns    Russell Henley        Shane Lowry
# 46       Rory McIlroy         Sam Burns        Shane Lowry
# 47  Xander Schauffele      Ludvig Aberg           Max Homa
# 50          Aaron Rai       Adam Schenk        Adam Hadwin
# 53  Xander Schauffele    Billy Horschel           Tom Hoge
# 59  Xander Schauffele     Akshay Bhatia   Matt Fitzpatrick
# 61  Xander Schauffele      Ludvig Aberg         Alex Noren
# 62  Xander Schauffele        Si Woo Kim        Ben Griffin
# 66  Scottie Scheffler         Sam Burns   Maverick McNealy
# 68  Scottie Scheffler   Patrick Cantlay        Shane Lowry
# 69  Xander Schauffele     Akshay Bhatia       Brian Harman
#
#                     Golfer4                  Golfer5               Golfer6  \
# 0   Christiaan Bezuidenhout           Denny McCarthy          Brian Harman
# 1                       NaN                      NaN                   NaN
# 4              Matt McCarty        Bryson DeChambeau         Takumi Kanaya
# 6   Christiaan Bezuidenhout                      NaN                   NaN
# 7               Ben Griffin           Austin Eckroat            Chris Kirk
# 10         Robert MacIntyre                Cam Davis          Brian Harman
# 15             Brian Harman                      NaN                   NaN
# 18                Aaron Rai             Brian Harman           Nick Dunlap
# 19              Nick Taylor                 Kevin Yu              Chan Kim
# 20                 Jon Rahm                      NaN                   NaN
# 21        Frankie Capan III        Aldrich Potgieter           Karl Vilips
# 22                 Tom Hoge                      NaN                   NaN
# 23           Austin Eckroat              Ben Griffin                   NaN
# 30          Rasmus Hojgaard  Christiaan Bezuidenhout      Nicolai Hojgaard
# 32                      NaN                      NaN                   NaN
# 38               Si Woo Kim                      NaN                   NaN
# 39             Brian Harman                      NaN                   NaN
# 40          Taylor Pendrith               Alex Noren           Ben Griffin
# 41         Maverick McNealy                 Tom Hoge             Aaron Rai
# 42              Min Woo Lee              Adam Hadwin            Alex Noren
# 43           Davis Thompson              Sepp Straka              Tom Hoge
# 46                Aaron Rai               Alex Noren       Taylor Pendrith
# 47                      NaN                      NaN                   NaN
# 50               Alex Noren           Billy Horschel            Chris Kirk
# 53                Sam Burns         Maverick McNealy     Frankie Capan III
# 59                Cam Davis          Patrick Rodgers        Matthieu Pavon
# 61                Aaron Rai          Taylor Pendrith                   NaN
# 62             Matt McCarty            Corey Conners            Harry Hall
# 66              Justin Rose        Frankie Capan III                   NaN
# 68                      NaN                      NaN                   NaN
# 69            Jordan Spieth           Keegan Bradley  Michael Thorbjornsen
#
#                  Golfer7            Golfer8  ... Injury2 Injury3  Injury4  \
# 0             Alex Noren                NaN  ...     0.0    0.00     0.00
# 1                    NaN                NaN  ...     0.0    0.00     0.00
# 4   Michael Thorbjornsen                NaN  ...     0.0    0.00     0.00
# 6                    NaN                NaN  ...     0.0    0.00     0.00
# 7                    NaN                NaN  ...     0.0    0.00     0.00
# 10                   NaN                NaN  ...     0.0    0.00     0.00
# 15                   NaN                NaN  ...     0.0    0.00     0.00
# 18                   NaN                NaN  ...     0.0    0.00     0.00
# 19                   NaN                NaN  ...     0.0    0.00     0.00
# 20                   NaN                NaN  ...     0.0    0.00     0.00
# 21        Matthew Riedel  Braden Thornberry  ...     0.0    0.00     0.00
# 22                   NaN                NaN  ...     0.0    0.00     0.00
# 23                   NaN                NaN  ...     0.0    0.00     0.00
# 30            Alex Noren    Erik Van Rooyen  ...     0.0    0.00     0.00
# 32                   NaN                NaN  ...     0.0    0.00     0.00
# 38                   NaN                NaN  ...     0.0    9.25     0.00
# 39                   NaN                NaN  ...     0.0    0.00     0.00
# 40         Daniel Berger    Nico Echavarria  ...     0.0    0.00     0.00
# 41            Alex Noren        Ben Griffin  ...     0.0    0.00     0.00
# 42             Cam Davis       Brian Harman  ...     0.0    0.00     0.00
# 43        Austin Eckroat       Brian Harman  ...     0.0    0.00     0.00
# 46           Ben Griffin       Andrew Novak  ...     0.0    0.00     0.00
# 47                   NaN                NaN  ...     0.0    0.00     0.00
# 50        Keith Mitchell     Stephan Jaeger  ...     0.0    0.00     0.75
# 53     Aldrich Potgieter                NaN  ...     0.0    0.00     0.00
# 59     Bryson DeChambeau                NaN  ...     0.0    0.00     0.00
# 61                   NaN                NaN  ...     0.0    0.75     0.00
# 62        Matthieu Pavon       Thomas Detry  ...     0.0    0.00     0.00
# 66                   NaN                NaN  ...     0.0    0.00     0.00
# 68                   NaN                NaN  ...     0.0    0.00     0.00
# 69                   NaN                NaN  ...     0.0    0.00     0.00
#
#     Injury5  Injury6  Injury7  Injury8  Injury9  Injury10  Max_Injury_Salary
# 0      0.00     0.00     0.75      0.0     0.00       0.0               6.50
# 1      0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 4      0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 6      0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 7      0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 10     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 15     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 18     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 19     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 20     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 21     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 22     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 23     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 30     0.00     0.00     0.75      0.0     0.00       0.0               0.75
# 32     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 38     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 39     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 40     0.75     0.00     0.00      0.0     0.00       0.0               0.75
# 41     0.00     0.00     0.75      0.0     0.00       0.0               0.75
# 42     0.00     0.75     0.00      0.0     0.00       0.0               0.75
# 43     0.00     0.00     0.00      0.0     0.75       0.0               0.75
# 46     0.75     0.00     0.00      0.0     0.00       0.0               0.75
# 47     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 50     0.00     0.00     0.00      0.0     0.00       6.5               6.50
# 53     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 59     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 61     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 62     0.00     0.00     0.00      0.0     0.00       0.0               6.50
# 66     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 68     0.00     0.00     0.00      0.0     0.00       0.0               9.25
# 69     0.00     0.00     0.00      0.0     0.00       0.0               6.50
#
# [31 rows x 23 columns]

# %%
# Read salaries
salaries = pd.read_csv('Salaries.csv')

# Join salaries onto the injury sub
rosters = rosters.merge(salaries, how='left', left_on='Golfer0', right_on='Golfer')
rosters.rename(columns={'Salary': 'Sub_Salary'}, inplace=True)
rosters.drop(columns=['Golfer','Owners'], inplace=True)
rosters
# Out:
#                                Team Name            Golfer0  \
# 0                                      7          Aaron Rai
# 1                               #winning    Patrick Cantlay
# 2                       $14 the Hard Way        Justin Rose
# 3                              19th Hole   Hideki Matsuyama
# 4                        2BallChinPutter  Xander Schauffele
# ..                                   ...                ...
# 67                         Walking Bogey    Taylor Pendrith
# 68  Who's Up and Why Aren't They Hitting    Sahith Theegala
# 69                         Wrecking Crew     Davis Thompson
# 70                                 WVU69       Taylor Moore
# 71                            Young Guns         Chris Kirk
#
#               Golfer1           Golfer2           Golfer3  \
# 0   Xander Schauffele     Akshay Bhatia       Min Woo Lee
# 1   Scottie Scheffler  Hideki Matsuyama          Jon Rahm
# 2        Ludvig Aberg   Sahith Theegala           Tom Kim
# 3     Collin Morikawa      Ludvig Aberg         Aaron Rai
# 4   Scottie Scheffler   Rasmus Hojgaard     Rickie Fowler
# ..                ...               ...               ...
# 67       Ludvig Aberg        Sungjae Im  Maverick McNealy
# 68  Scottie Scheffler   Patrick Cantlay       Shane Lowry
# 69  Xander Schauffele     Akshay Bhatia      Brian Harman
# 70     Austin Eckroat     Corey Conners         Eric Cole
# 71      Akshay Bhatia  Matt Fitzpatrick       Nick Dunlap
#
#                     Golfer4                  Golfer5               Golfer6  \
# 0   Christiaan Bezuidenhout           Denny McCarthy          Brian Harman
# 1                       NaN                      NaN                   NaN
# 2               Nick Dunlap            Brooks Koepka     Bryson DeChambeau
# 3         Bryson DeChambeau     Michael Thorbjornsen           Karl Vilips
# 4              Matt McCarty        Bryson DeChambeau         Takumi Kanaya
# ..                      ...                      ...                   ...
# 67           Davis Thompson           Austin Eckroat            Harry Hall
# 68                      NaN                      NaN                   NaN
# 69            Jordan Spieth           Keegan Bradley  Michael Thorbjornsen
# 70             Matt McCarty              Nick Dunlap             Sam Burns
# 71         Robert MacIntyre  Christiaan Bezuidenhout       Taylor Pendrith
#
#                  Golfer7           Golfer8  ... Injury3 Injury4  Injury5  \
# 0             Alex Noren               NaN  ...     0.0     0.0      0.0
# 1                    NaN               NaN  ...     0.0     0.0      0.0
# 2                    NaN               NaN  ...     0.0     0.0      0.0
# 3                    NaN               NaN  ...     0.0     0.0      0.0
# 4   Michael Thorbjornsen               NaN  ...     0.0     0.0      0.0
# ..                   ...               ...  ...     ...     ...      ...
# 67           Ben Griffin  Patrick Fishburn  ...     0.0     0.0      0.0
# 68                   NaN               NaN  ...     0.0     0.0      0.0
# 69                   NaN               NaN  ...     0.0     0.0      0.0
# 70           Sepp Straka   Taylor Pendrith  ...     0.0     0.0      0.0
# 71             Aaron Rai          Tom Hoge  ...     0.0     0.0      0.0
#
#     Injury6  Injury7  Injury8  Injury9  Injury10  Max_Injury_Salary  \
# 0       0.0     0.75      0.0      0.0       0.0               6.50
# 1       0.0     0.00      0.0      0.0       0.0               9.25
# 2       0.0     0.00      0.0      0.0       0.0               0.00
# 3       0.0     0.00      0.0      0.0       0.0               0.00
# 4       0.0     0.00      0.0      0.0       0.0               9.25
# ..      ...      ...      ...      ...       ...                ...
# 67      0.0     0.00      0.0      0.0       0.0               0.00
# 68      0.0     0.00      0.0      0.0       0.0               9.25
# 69      0.0     0.00      0.0      0.0       0.0               6.50
# 70      0.0     0.00      0.0      0.0       0.0               0.00
# 71      0.0     0.00      0.0      0.0       0.0               0.00
#
#     Sub_Salary
# 0         1.25
# 1         4.00
# 2         0.75
# 3         4.50
# 4         6.50
# ..         ...
# 67        1.25
# 68        3.50
# 69        1.50
# 70        0.50
# 71        1.00
#
# [72 rows x 24 columns]

# %%
# attach pga earnings to each golfer, including the injury sub (Golfer0)
for i in range(0,11):
    golfer_col = f"Golfer{i}"
    earnings_col = f"Earnings{i}"
    rosters[earnings_col] = rosters[golfer_col].map(pga_results.set_index("PLAYER")["EARNINGS"])
#    rosters[earnings_col] = pd.to_numeric(
#        rosters[golfer_col].map(pga_results.set_index("PLAYER")["EARNINGS"]),
#        errors='coerce'
#    ).fillna(0)
rosters
# Out:
#                                Team Name            Golfer0  \
# 0                                      7          Aaron Rai
# 1                               #winning    Patrick Cantlay
# 2                       $14 the Hard Way        Justin Rose
# 3                              19th Hole   Hideki Matsuyama
# 4                        2BallChinPutter  Xander Schauffele
# ..                                   ...                ...
# 67                         Walking Bogey    Taylor Pendrith
# 68  Who's Up and Why Aren't They Hitting    Sahith Theegala
# 69                         Wrecking Crew     Davis Thompson
# 70                                 WVU69       Taylor Moore
# 71                            Young Guns         Chris Kirk
#
#               Golfer1           Golfer2           Golfer3  \
# 0   Xander Schauffele     Akshay Bhatia       Min Woo Lee
# 1   Scottie Scheffler  Hideki Matsuyama          Jon Rahm
# 2        Ludvig Aberg   Sahith Theegala           Tom Kim
# 3     Collin Morikawa      Ludvig Aberg         Aaron Rai
# 4   Scottie Scheffler   Rasmus Hojgaard     Rickie Fowler
# ..                ...               ...               ...
# 67       Ludvig Aberg        Sungjae Im  Maverick McNealy
# 68  Scottie Scheffler   Patrick Cantlay       Shane Lowry
# 69  Xander Schauffele     Akshay Bhatia      Brian Harman
# 70     Austin Eckroat     Corey Conners         Eric Cole
# 71      Akshay Bhatia  Matt Fitzpatrick       Nick Dunlap
#
#                     Golfer4                  Golfer5               Golfer6  \
# 0   Christiaan Bezuidenhout           Denny McCarthy          Brian Harman
# 1                       NaN                      NaN                   NaN
# 2               Nick Dunlap            Brooks Koepka     Bryson DeChambeau
# 3         Bryson DeChambeau     Michael Thorbjornsen           Karl Vilips
# 4              Matt McCarty        Bryson DeChambeau         Takumi Kanaya
# ..                      ...                      ...                   ...
# 67           Davis Thompson           Austin Eckroat            Harry Hall
# 68                      NaN                      NaN                   NaN
# 69            Jordan Spieth           Keegan Bradley  Michael Thorbjornsen
# 70             Matt McCarty              Nick Dunlap             Sam Burns
# 71         Robert MacIntyre  Christiaan Bezuidenhout       Taylor Pendrith
#
#                  Golfer7           Golfer8  ... Earnings1 Earnings2  \
# 0             Alex Noren               NaN  ...       NaN       NaN
# 1                    NaN               NaN  ...       NaN   52080.0
# 2                    NaN               NaN  ...   33945.0   22646.0
# 3                    NaN               NaN  ...       NaN   33945.0
# 4   Michael Thorbjornsen               NaN  ...       NaN       NaN
# ..                   ...               ...  ...       ...       ...
# 67           Ben Griffin  Patrick Fishburn  ...   33945.0  418500.0
# 68                   NaN               NaN  ...       NaN       NaN
# 69                   NaN               NaN  ...       NaN       NaN
# 70           Sepp Straka   Taylor Pendrith  ...       0.0       NaN
# 71             Aaron Rai          Tom Hoge  ...       NaN       NaN
#
#     Earnings3  Earnings4  Earnings5  Earnings6  Earnings7  Earnings8  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         0.0        NaN        0.0        NaN        NaN        NaN
# 4         NaN        0.0        NaN        0.0        0.0        NaN
# ..        ...        ...        ...        ...        ...        ...
# 67    22646.0        NaN        0.0        NaN        0.0        0.0
# 68        0.0        NaN        NaN        NaN        NaN        NaN
# 69        NaN        NaN   132732.0        0.0        NaN        NaN
# 70    19716.0        0.0        NaN        NaN        NaN   302250.0
# 71        NaN        NaN        NaN   302250.0        0.0        NaN
#
#     Earnings9  Earnings10
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# ..        ...         ...
# 67        NaN         NaN
# 68        NaN         NaN
# 69        NaN         NaN
# 70    22646.0         NaN
# 71        NaN         0.0
#
# [72 rows x 35 columns]

# %%
# If the injury sub salary is highest salaried injured golf (Max_Injury_Salary) then don't count Golfer0 earnings
# Note we also don't count Golfer0 earnings if no golfers on the team are injured, because Max_Injury_Salary = 0
rosters.loc[rosters['Sub_Salary'] > rosters['Max_Injury_Salary'], 'Earnings0'] = 0
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.reset_option('display')
#rosters

# Sum the earnings for the week
rosters['Tourney_Nb'] = Global_Tourney_Nb
rosters['Earn_Sum_Tourney'] = rosters[[f'Earnings{i}' for i in range(11)]].sum(axis=1)
rosters['Earn_Sum_YTD'] = 0
rosters['Payout_Sum_YTD'] = 0
rosters = rosters.sort_values(by=['Earn_Sum_Tourney'], ascending=False)
rosters
# Out:
#                   Team Name                  Golfer0            Golfer1  \
# 5             3 Finger Pour              Justin Rose    Jhonattan Vegas
# 28  General Patton's Troops               Jake Knapp       Ludvig Aberg
# 16           Blurry Golfers                 Tom Hoge    Collin Morikawa
# 57                     Slog               Alex Noren        Ben Griffin
# 46             Lump of Clay          Tommy Fleetwood       Rory McIlroy
# ..                      ...                      ...                ...
# 22                El Quatro        Xander Schauffele  Scottie Scheffler
# 38              I know ball          Collin Morikawa          Aaron Rai
# 29                Gimme Dat  Christiaan Bezuidenhout    Collin Morikawa
# 48                  MoB Inc        Bryson DeChambeau       Rory McIlroy
# 51                 Q School           Keegan Bradley         Tony Finau
#
#              Golfer2            Golfer3           Golfer4          Golfer5  \
# 5         Bud Cauley     Russell Henley      Brian Harman         Tom Hoge
# 28   Patrick Cantlay     Harris English  Maverick McNealy     Brian Harman
# 16    Viktor Hovland     Harris English       Min Woo Lee       Chris Kirk
# 57         Sam Burns    Taylor Pendrith         Aaron Rai     Rory McIlroy
# 46         Sam Burns        Shane Lowry         Aaron Rai       Alex Noren
# ..               ...                ...               ...              ...
# 22     Cameron Young           Jon Rahm          Tom Hoge              NaN
# 38     Akshay Bhatia  Scottie Scheffler        Si Woo Kim              NaN
# 29     Justin Thomas          Aaron Rai    Russell Henley  Rasmus Hojgaard
# 48  Matt Fitzpatrick        Shane Lowry    Davis Thompson    Wyndham Clark
# 51        Adam Scott       Brian Harman   Collin Morikawa       Si Woo Kim
#
#              Golfer6          Golfer7            Golfer8  ... Earnings5  \
# 5            Tom Kim  Sahith Theegala     Harris English  ...       NaN
# 28    Stephan Jaeger   Patton Kizzire   Patrick Fishburn  ...       NaN
# 16         Doug Ghim              NaN                NaN  ...       NaN
# 57  Maverick McNealy        Doug Ghim  Thirston Lawrence  ...       NaN
# 46   Taylor Pendrith      Ben Griffin       Andrew Novak  ...       NaN
# ..               ...              ...                ...  ...       ...
# 22               NaN              NaN                NaN  ...       NaN
# 38               NaN              NaN                NaN  ...       NaN
# 29               NaN              NaN                NaN  ...       NaN
# 48               NaN              NaN                NaN  ...       NaN
# 51  Nicolai Hojgaard              NaN                NaN  ...       0.0
#
#    Earnings6  Earnings7  Earnings8  Earnings9  Earnings10  Tourney_Nb  \
# 5        NaN    22646.0  1674000.0    19716.0         NaN           3
# 28       0.0        NaN        0.0        NaN         NaN           3
# 16       0.0        NaN        NaN        NaN         NaN           3
# 57   22646.0        0.0        NaN   641700.0         0.0           3
# 46  302250.0        0.0   641700.0        0.0         NaN           3
# ..       ...        ...        ...        ...         ...         ...
# 22       NaN        NaN        NaN        NaN         NaN           3
# 38       NaN        NaN        NaN        NaN         NaN           3
# 29       NaN        NaN        NaN        NaN         NaN           3
# 48       NaN        NaN        NaN        NaN         NaN           3
# 51       NaN        NaN        NaN        NaN         NaN           3
#
#     Earn_Sum_Tourney  Earn_Sum_YTD  Payout_Sum_YTD
# 5          1750307.0             0               0
# 28         1730591.0             0               0
# 16         1674000.0             0               0
# 57          966596.0             0               0
# 46          943950.0             0               0
# ..               ...           ...             ...
# 22               0.0             0               0
# 38               0.0             0               0
# 29               0.0             0               0
# 48               0.0             0               0
# 51               0.0             0               0
#
# [72 rows x 39 columns]

# %%
# Read in tournament details
tourneys = pd.read_csv('Tournaments.csv')
# Filter down to just this week's injuries
cur_tourney = tourneys[tourneys['Tourney_Nb'] == Global_Tourney_Nb]
cur_tourney
# Out:
#    Tourney_Nb  Period        Dates  Payout Tier              Tournament  Pay1  \
# 2           3       1  Jan 22 - 25            1  Farmers Insurance Open    35
#
#    Pay2  Pay3  Pay4  Pay5  Pay6  Pay7
# 2    25    15    10     5     0     0

# %%
tourney_results = pd.merge(rosters, cur_tourney, left_on='Tourney_Nb', right_on='Tourney_Nb', how='inner')
# Add the 'tourney_rank' column based on the ranking of 'Earn_Sum_Tourney'
tourney_results['tourney_rank_min'] = tourney_results['Earn_Sum_Tourney'].rank(ascending=False, method='min')
tourney_results['tourney_rank_reverse'] = tourney_results['Earn_Sum_Tourney'].rank(ascending=True, method='min')
tourney_results['tourney_rank_max'] = Global_Team_Cnt + 1 - tourney_results['tourney_rank_reverse']

def sum_pay_range(row):
    # Convert to integers (just in case they are floats)
    start_rank = int(row['tourney_rank_min'])
    end_rank = int(row['tourney_rank_max'])
    
    # Initialize sum variable
    total_sum = 0
    
    # Loop through the rank range and sum Pay columns if they exist
    for i in range(start_rank, end_rank + 1):
        column_name = f'Pay{i}'
        if column_name in row:  # Check if the column exists
            total_sum += row[column_name]
        else:
            total_sum += 0  # If column doesn't exist, assume its value is zero
    
    return total_sum

# Apply the function to each row and create a new column for the sum
tourney_results['pay_sum'] = tourney_results.apply(sum_pay_range, axis=1)
tourney_results['weekly_payout'] = tourney_results['pay_sum'] / (tourney_results['tourney_rank_max'] - tourney_results['tourney_rank_min'] + 1)
tourney_results
# Out:
#                   Team Name                  Golfer0            Golfer1  \
# 0             3 Finger Pour              Justin Rose    Jhonattan Vegas
# 1   General Patton's Troops               Jake Knapp       Ludvig Aberg
# 2            Blurry Golfers                 Tom Hoge    Collin Morikawa
# 3                      Slog               Alex Noren        Ben Griffin
# 4              Lump of Clay          Tommy Fleetwood       Rory McIlroy
# ..                      ...                      ...                ...
# 67                El Quatro        Xander Schauffele  Scottie Scheffler
# 68              I know ball          Collin Morikawa          Aaron Rai
# 69                Gimme Dat  Christiaan Bezuidenhout    Collin Morikawa
# 70                  MoB Inc        Bryson DeChambeau       Rory McIlroy
# 71                 Q School           Keegan Bradley         Tony Finau
#
#              Golfer2            Golfer3           Golfer4          Golfer5  \
# 0         Bud Cauley     Russell Henley      Brian Harman         Tom Hoge
# 1    Patrick Cantlay     Harris English  Maverick McNealy     Brian Harman
# 2     Viktor Hovland     Harris English       Min Woo Lee       Chris Kirk
# 3          Sam Burns    Taylor Pendrith         Aaron Rai     Rory McIlroy
# 4          Sam Burns        Shane Lowry         Aaron Rai       Alex Noren
# ..               ...                ...               ...              ...
# 67     Cameron Young           Jon Rahm          Tom Hoge              NaN
# 68     Akshay Bhatia  Scottie Scheffler        Si Woo Kim              NaN
# 69     Justin Thomas          Aaron Rai    Russell Henley  Rasmus Hojgaard
# 70  Matt Fitzpatrick        Shane Lowry    Davis Thompson    Wyndham Clark
# 71        Adam Scott       Brian Harman   Collin Morikawa       Si Woo Kim
#
#              Golfer6          Golfer7            Golfer8  ... Pay3 Pay4  Pay5  \
# 0            Tom Kim  Sahith Theegala     Harris English  ...   15   10     5
# 1     Stephan Jaeger   Patton Kizzire   Patrick Fishburn  ...   15   10     5
# 2          Doug Ghim              NaN                NaN  ...   15   10     5
# 3   Maverick McNealy        Doug Ghim  Thirston Lawrence  ...   15   10     5
# 4    Taylor Pendrith      Ben Griffin       Andrew Novak  ...   15   10     5
# ..               ...              ...                ...  ...  ...  ...   ...
# 67               NaN              NaN                NaN  ...   15   10     5
# 68               NaN              NaN                NaN  ...   15   10     5
# 69               NaN              NaN                NaN  ...   15   10     5
# 70               NaN              NaN                NaN  ...   15   10     5
# 71  Nicolai Hojgaard              NaN                NaN  ...   15   10     5
#
#     Pay6  Pay7  tourney_rank_min  tourney_rank_reverse  tourney_rank_max  \
# 0      0     0               1.0                  72.0               1.0
# 1      0     0               2.0                  71.0               2.0
# 2      0     0               3.0                  70.0               3.0
# 3      0     0               4.0                  69.0               4.0
# 4      0     0               5.0                  68.0               5.0
# ..   ...   ...               ...                   ...               ...
# 67     0     0              66.0                   1.0              72.0
# 68     0     0              66.0                   1.0              72.0
# 69     0     0              66.0                   1.0              72.0
# 70     0     0              66.0                   1.0              72.0
# 71     0     0              66.0                   1.0              72.0
#
#     pay_sum  weekly_payout
# 0        35           35.0
# 1        25           25.0
# 2        15           15.0
# 3        10           10.0
# 4         5            5.0
# ..      ...            ...
# 67        0            0.0
# 68        0            0.0
# 69        0            0.0
# 70        0            0.0
# 71        0            0.0
#
# [72 rows x 55 columns]

# %%
if Global_Tourney_Nb == 1:
    tourney_results.to_csv('YTD_Earnings_Detail.csv', index=False)
    print("CSV file created: 'YTD_Earnings_Detail.csv'")
else:
    print("Global_Tourney_Nb is not 1. No file created.")
# Out:
# Global_Tourney_Nb is not 1. No file created.

# %%
# read YTD Earnings Detail
# Delete rows where 'Tourney_Nb' is equal to 'Global_Tourney_Nb'.  Do this in case I need to re-run a week
# Append the tourney_results dataframe to the bottom of the ytd dataframe
ytd_dets = pd.read_csv('YTD_Earnings_Detail.csv')
ytd_dets = ytd_dets[ytd_dets['Tourney_Nb'] < Global_Tourney_Nb]
ytd_dets = pd.concat([ytd_dets, tourney_results],ignore_index=True)
ytd_dets
# Out:
#             Team Name                  Golfer0            Golfer1  \
# 0            #winning          Patrick Cantlay  Scottie Scheffler
# 1            #winning          Patrick Cantlay  Scottie Scheffler
# 2    $14 the Hard Way              Justin Rose       Ludvig Aberg
# 3    $14 the Hard Way              Justin Rose       Ludvig Aberg
# 4           19th Hole         Hideki Matsuyama    Collin Morikawa
# ..                ...                      ...                ...
# 211         El Quatro        Xander Schauffele  Scottie Scheffler
# 212       I know ball          Collin Morikawa          Aaron Rai
# 213         Gimme Dat  Christiaan Bezuidenhout    Collin Morikawa
# 214           MoB Inc        Bryson DeChambeau       Rory McIlroy
# 215          Q School           Keegan Bradley         Tony Finau
#
#               Golfer2            Golfer3            Golfer4  \
# 0    Hideki Matsuyama           Jon Rahm                NaN
# 1    Hideki Matsuyama           Jon Rahm                NaN
# 2     Sahith Theegala            Tom Kim        Nick Dunlap
# 3     Sahith Theegala            Tom Kim        Nick Dunlap
# 4        Ludvig Aberg          Aaron Rai  Bryson DeChambeau
# ..                ...                ...                ...
# 211     Cameron Young           Jon Rahm           Tom Hoge
# 212     Akshay Bhatia  Scottie Scheffler         Si Woo Kim
# 213     Justin Thomas          Aaron Rai     Russell Henley
# 214  Matt Fitzpatrick        Shane Lowry     Davis Thompson
# 215        Adam Scott       Brian Harman    Collin Morikawa
#
#                   Golfer5            Golfer6 Golfer7 Golfer8  ... Pay3 Pay4  \
# 0                     NaN                NaN     NaN     NaN  ...   15   10
# 1                     NaN                NaN     NaN     NaN  ...   15   10
# 2           Brooks Koepka  Bryson DeChambeau     NaN     NaN  ...   15   10
# 3           Brooks Koepka  Bryson DeChambeau     NaN     NaN  ...   15   10
# 4    Michael Thorbjornsen        Karl Vilips     NaN     NaN  ...   15   10
# ..                    ...                ...     ...     ...  ...  ...  ...
# 211                   NaN                NaN     NaN     NaN  ...   15   10
# 212                   NaN                NaN     NaN     NaN  ...   15   10
# 213       Rasmus Hojgaard                NaN     NaN     NaN  ...   15   10
# 214         Wyndham Clark                NaN     NaN     NaN  ...   15   10
# 215            Si Woo Kim   Nicolai Hojgaard     NaN     NaN  ...   15   10
#
#      Pay5  Pay6  Pay7  tourney_rank_min  tourney_rank_reverse  \
# 0       5     0     0              41.0                  31.0
# 1       5     0     0              22.0                  50.0
# 2       5     0     0              32.0                  41.0
# 3       5     0     0              56.0                  16.0
# 4       5     0     0              65.0                   1.0
# ..    ...   ...   ...               ...                   ...
# 211     5     0     0              66.0                   1.0
# 212     5     0     0              66.0                   1.0
# 213     5     0     0              66.0                   1.0
# 214     5     0     0              66.0                   1.0
# 215     5     0     0              66.0                   1.0
#
#      tourney_rank_max  pay_sum  weekly_payout
# 0                42.0        0            0.0
# 1                23.0        0            0.0
# 2                32.0        0            0.0
# 3                57.0        0            0.0
# 4                72.0        0            0.0
# ..                ...      ...            ...
# 211              72.0        0            0.0
# 212              72.0        0            0.0
# 213              72.0        0            0.0
# 214              72.0        0            0.0
# 215              72.0        0            0.0
#
# [216 rows x 55 columns]

# %%
# Sort the DataFrame by 'Team Name' and 'Tourney_Nb'
ytd_dets = ytd_dets.sort_values(by=['Team Name', 'Tourney_Nb'], ascending=[True, True])

# Calculate the running total for 'Earn_Sum_YTD' for each 'Team Name'
ytd_dets['Earn_Sum_YTD'] = ytd_dets.groupby('Team Name')['Earn_Sum_Tourney'].cumsum()
ytd_dets['Payout_Sum_YTD'] = ytd_dets.groupby('Team Name')['weekly_payout'].cumsum()

# Write out the updated ytd_earnings
ytd_dets.to_csv('YTD_Earnings_Detail.csv', index=False)

# %%
golfer_names = [f'Golfer{i}' for i in range(0,11)]
df_golfers = ytd_dets[['Tourney_Nb','Team Name'] + golfer_names]

golfer_earnings = [f'Earnings{i}' for i in range(0,11)]
df_earnings = ytd_dets[['Tourney_Nb','Team Name'] + golfer_earnings]
df_earnings = df_earnings.rename(columns={f'Earnings{i}': f'Golfer{i}' for i in range(0,11)})

df_ytd_dets = pd.concat([df_golfers, df_earnings],ignore_index=True)
df_ytd_dets = df_ytd_dets.sort_values(by=['Tourney_Nb','Team Name'], ascending=[True,True])
df_ytd_dets = df_ytd_dets.rename(columns={'Golfer0': 'InjurySub'})
df_ytd_dets = df_ytd_dets.fillna("")
df_ytd_dets = df_ytd_dets.replace(0,"")
df_ytd_dets.to_csv('YTD_Details_For_Web.csv', index=False)
#df_ytd_dets

# %%
# Use a set to collect unique golfer names with no match
# This is just a check to make sure I'm not missing salaries for any golfers
missing_golfers = set()

for i in range(0,11):
    golfer_col = f"Golfer{i}"
    salary_col = f"salary{i}"
    rosters[salary_col] = rosters[golfer_col].map(salaries.set_index("Golfer")["Salary"])
# Find unmatched golfers for the current column
    unmatched = rosters.loc[rosters[salary_col].isna(), golfer_col]
    missing_golfers.update(unmatched)  # Add unmatched golfers to the set

# Convert set to list for easier display or further processing
missing_golfers_list = list(missing_golfers)
print("Golfers with no matching salary:")
print(missing_golfers_list)

# %%
rosters['salary_sum'] = rosters[[f'salary{i}' for i in range(1,11)]].sum(axis=1)
rosters
